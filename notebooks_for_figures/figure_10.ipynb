# %%
#!/usr/bin/env python

import sys
import os
absFilePath = os.path.abspath('attractor_switching.py')
fileDir = os.path.dirname(absFilePath)
parentDir = os.path.dirname(fileDir)

# change working directory to the project file of codes, use parentDir else
sys.path.append(parentDir+'/src')

import numpy as np
import matplotlib
import pickle
import matplotlib.pyplot as plt
from pylab import figure, cm
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/t/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-83d4ee5b3b15>", line 5, in <module>
#     absFilePath = os.path.abspath('attractor_switching.py')
#   File "/home/t/anaconda3/lib/python3.6/posixpath.py", line 376, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/t/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1863, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/t/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/t/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/home/t/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/t/anaconda3/lib/python3.6/inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/t/anaconda3/lib/python3.6/inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/t/anaconda3/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/t/anaconda3/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/home/t/anaconda3/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/t/anaconda3/lib/python3.6/posixpath.py", line 376, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# ---------------------------------------------------------------------------

# %%
filename=fileDir+'/data/data_figure_10'
with open(filename, 'rb') as pickle_file:
    data = pickle.load(pickle_file)
bifurcation_ar=data['bifurcation_ar']
energy_t_smaller_tc=data['energy_t_smaller_tc']
energy_t_larger_tc=data['energy_t_larger_tc']
degree=data['degree']
figures=['10a','10b','10c','10d']

# %%
b=0
lw=2
fs=30

x=degree
y=np.mean(energy_t_smaller_tc,axis=-2)
yerror=np.std(energy_t_smaller_tc,axis=-2)

e=0
i=0
cols=['black','red']
labels=['$t<t_c$','$t>t_c$']

kwargs = dict(ecolor='k', color='k', capsize=2,
              elinewidth=1.1, linewidth=0.6, ms=11)

for b,bifurcation in enumerate(bifurcation_ar):
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,6))

    ax.errorbar(x,y[b] ,yerr=yerror[b], fmt='o', mfc=cols[e],label=labels[e], **kwargs)
    ax.set_xlabel('$d_k$',size=fs)
    ax.set_ylabel('$E_k$',size=fs)
    ax.tick_params(labelsize=fs)
    ax.grid(True)
    ax.set_ylim(0,np.max(y[b])+np.max(yerror[b]))
    ax.legend(loc='lower right', frameon=True,fontsize=fs)
    ax.legend(loc='upper right', ncol=1, frameon=True,fontsize=fs-9)
    #ax.set_title(bifurcation+' bifurcation',size=fs, pad=20,color='r')


    plt.savefig(fileDir+'/figures/figure_'+figures[i]+'.png', bbox_inches='tight') 
    plt.show()
    i+=1
e=1
    
y=np.mean(energy_t_larger_tc,axis=-2)
yerror=np.std(energy_t_larger_tc,axis=-2)
for b,bifurcation in enumerate(bifurcation_ar):
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,6))

    ax.errorbar(x,y[b] ,yerr=yerror[b], fmt='o', mfc=cols[e],label=labels[e], **kwargs)
    ax.set_xlabel('d',size=fs)
    ax.set_ylabel('$E_k$',size=fs)
    ax.tick_params(labelsize=fs)
    ax.grid(True)
    ax.set_ylim(0,np.max(y[b])+np.max(yerror[b]))
    ax.legend(loc='lower right', frameon=True,fontsize=fs)
    ax.legend(loc='upper right', ncol=1, frameon=True,fontsize=fs-9)
    #ax.set_title(bifurcation+' bifurcation',size=fs, pad=20,color='r')
    
    plt.savefig(fileDir+'/figures/figure_'+figures[i]+'.png', bbox_inches='tight')
    plt.show()
    i+=1
